# %% [markdown]
# <a href="https://colab.research.google.com/github/ranga-godhandaraman/custom-imagenette-dataset/blob/main/fantasy_dataset_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install datasets

# %%
import datasets

# %% [markdown]
# change the dataset name

# %%
dt = datasets.load_dataset("ranga-godhandaraman/fantasy-data")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/2 [00:00<?, ? examples/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
datapath= "/content/drive/MyDrive/data"

# %%
fs= os.listdir(datapath)

# %%
fs
# Out:
# ['ranga.jpg',
#  'Anu Emmanuel-gen.jpeg',
#  'anupama-gen.jpeg',
#  'Aishwarya Rajesh-gen.jpeg',
#  "Genelia D'Souza1-gen.jpeg",
#  'Asin Thottumkal-gen.jpg',
#  "Ileana D'Cruz-gen.jpeg",
#  'Catherine Tresa-gen.jpeg',
#  'parvathy-gen.jpeg',
#  'Meera Jasmine2-gen.jpg',
#  'Pooja Hegde1-gen.jpg',
#  'manju warrier-gen.jpg',
#  'Shraddha Srinath-gen.jpeg',
#  'Vedhika Kumar-gen.jpeg',
#  'Shalini Ajith-gen.jpeg',
#  'mallu.jpeg',
#  'andriea.jpeg',
#  'anjali.jpeg',
#  'shriya.jpeg',
#  'jothika.jpeg',
#  'saipallavi.jpeg',
#  'amalapaul.jpeg',
#  'priyamani.jpeg',
#  'nithyamenon.jpeg',
#  'rashmika.jpeg',
#  'angelina.jpeg',
#  'rakul.jpeg',
#  'tammu.jpeg',
#  'shruthi.jpeg',
#  'keerthi.jpeg',
#  'kajal.jpeg',
#  'trisha.jpeg',
#  'sammu.jpeg',
#  'andriea-gen.jpg',
#  'shruthi-gen.jpg',
#  'keerthi-gen.jpg',
#  'sammu-gen.jpg',
#  'rakul-gen.jpg',
#  'kaju-gen.jpg',
#  'mallu-gen.jpg',
#  'nithyamenon-gen.jpg',
#  'manju warrier.jpeg',
#  'priyamani-gen.jpg',
# ...

# %%
original = []
cartoonized = []
for i in fs:
  if '-gen'in i:
    cartoonized.append(i)
  else:
    original.append(i)

# %%
original.remove('.ipynb_checkpoints')

# %%
original
# Out:
# ['ranga.jpg',
#  'mallu.jpeg',
#  'andriea.jpeg',
#  'anjali.jpeg',
#  'shriya.jpeg',
#  'jothika.jpeg',
#  'saipallavi.jpeg',
#  'amalapaul.jpeg',
#  'priyamani.jpeg',
#  'nithyamenon.jpeg',
#  'rashmika.jpeg',
#  'angelina.jpeg',
#  'rakul.jpeg',
#  'tammu.jpeg',
#  'shruthi.jpeg',
#  'keerthi.jpeg',
#  'kajal.jpeg',
#  'trisha.jpeg',
#  'sammu.jpeg',
#  'manju warrier.jpeg',
#  'anupama .jpeg',
#  'parvathy.jpeg',
#  'Catherine Tresa.jpeg',
#  'rashikanna.jpg',
#  'Aishwarya Rajesh.jpeg',
#  'Vedhika Kumar.jpeg',
#  'Amrita Rao.jpeg',
#  "Genelia D'Souza.jpeg",
#  'Meera Jasmine.jpeg',
#  'Shalini Ajith.jpeg',
#  'Sneha Prasanna.jpeg',
#  "Ileana D'Cruz.jpeg",
#  'Shraddha Srinath.jpeg',
#  'Kriti Kharbanda.jpeg',
#  'Priya Bhavani Shankar.jpeg',
#  'Manjima Mohan.jpeg',
#  'Anu Emmanuel.jpeg',
#  'tapsee.jpg',
#  'Madonna Sebastian.jpeg',
#  'Pooja Hegde.jpg',
#  'Asin Thottumkal copy.jpg',
#  'Priya Mani.jpeg',
#  'srk1.jpg',
#  'srk2.jpg',
#  'salman1.jpg',
#  'salman2.jpg',
# ...

# %%
cartoonized
# Out:
# ['Anu Emmanuel-gen.jpeg',
#  'anupama-gen.jpeg',
#  'Aishwarya Rajesh-gen.jpeg',
#  "Genelia D'Souza1-gen.jpeg",
#  'Asin Thottumkal-gen.jpg',
#  "Ileana D'Cruz-gen.jpeg",
#  'Catherine Tresa-gen.jpeg',
#  'parvathy-gen.jpeg',
#  'Meera Jasmine2-gen.jpg',
#  'Pooja Hegde1-gen.jpg',
#  'manju warrier-gen.jpg',
#  'Shraddha Srinath-gen.jpeg',
#  'Vedhika Kumar-gen.jpeg',
#  'Shalini Ajith-gen.jpeg',
#  'andriea-gen.jpg',
#  'shruthi-gen.jpg',
#  'keerthi-gen.jpg',
#  'sammu-gen.jpg',
#  'rakul-gen.jpg',
#  'kaju-gen.jpg',
#  'mallu-gen.jpg',
#  'nithyamenon-gen.jpg',
#  'priyamani-gen.jpg',
#  'saipallavi-gen.jpg',
#  'trisha-gen.jpg',
#  'angelina-gen.jpg',
#  'shriya-gen.jpg',
#  'anjali-gen.jpg',
#  'rashikhanna-gen.jpg',
#  'amalapaul-gen.jpg',
#  'tammu-gen.jpg',
#  'rashmika-gen.jpg',
#  'tapsee-gen.jpg',
#  'jothika-gen.jpg',
#  'Sneha Prasanna-gen.jpeg',
#  'Madonna Sebastian-gen.jpeg',
#  'Priya Mani-gen.jpeg',
#  'Priya Bhavani Shankar-gen.jpeg',
# ...

# %% [markdown]
# ### for multiple prompts

# %%
# # prompt = "Transform the person into an artistic illustration resembling Wonder Woman"
# prompts = [
#     # "Create a visual interpretation of the individual as a character in a fantasy world",
#     # "Render the person as a mystical creature from mythology",
#     # "Imagine the person as the protagonist of a comic book",
#     # "Illustrate the person as a whimsical character in a children's book",
#     # "Portray the individual as a steampunk-inspired adventurer",
#     # "Transform the person into a futuristic cyborg",
#     # "Capture the essence of the individual as a surrealist masterpiece",
#     # "Depict the person as a character from a classic fairy tale",
#     # "Reimagine the individual as a superhero with unique powers",
#     # "Illustrate the person as a vibrant graffiti art mural",
#     # "Create a portrait of the person as a character in a Japanese anime",
#     # "Transform the individual into a gothic-inspired figure",
#     # "Portray the person as a celestial being amongst the stars",
#     # "Imagine the individual as a mythical creature from folklore",
#     # "Render the person as a character in a psychedelic dreamscape",
#     # "Illustrate the individual as a time-traveling explorer",
#     # "Capture the person's essence as a whimsical puppet",
#     # "Reimagine the individual as a medieval knight on a quest",
#     # "Depict the person as a magical being in an enchanted forest",
#     # "Transform the individual into a character from a sci-fi movie",
#     # "Create an artistic interpretation of the person as a tarot card",
#     # "Portray the individual as a figure in a surrealistic landscape",
#     # "Imagine the person as a legendary warrior from history",
#     # "Illustrate the individual as a character in a post-apocalyptic world",
#     # "Capture the essence of the person as a mythical Greek god or goddess",
#     # "Reimagine the individual as a character from a Shakespearean play",
#     # "Depict the person as a figure in a cosmic tapestry",
#     # "Transform the individual into an animated character from a Studio Ghibli film",
#     # "Portray the person as a character in a graphic novel",
#     # "Imagine the individual as a wandering nomad in a desert landscape",
#     # "Illustrate the person as a whimsical circus performer",
#     # "Capture the essence of the individual as a ghostly apparition",
#     # "Reimagine the person as a character in a Tim Burton-style world",
#     # "Depict the individual as a figure in an ancient mythological scene",
#     # "Transform the person into a character from a video game",
#     # "Portray the individual as a figure in a Renaissance painting",
#     # "Imagine the person as a character in a gothic horror novel",
#     # "Illustrate the individual as a figure in a futuristic cityscape",
#     # "Capture the essence of the person as a character in a fairy tale retelling",
#     # "Reimagine the individual as a wanderer in a magical realm"
# ]

# for prompt in prompts:
#     print(prompt)
#     # Here you would put your code to create or process the visual interpretation
#     print("-" * 50)  # Separating each prompt visually

# %%
# import random

# # Sort the images filenames
# sorted_original = sorted(original)
# sorted_cartoonized = sorted(cartoonized)

# # Shuffle the prompts randomly
# shuffled_prompts = random.sample(pr, len(pr))

# # Combine the sorted filenames with the shuffled prompts
# temp = []
# min_length = min(len(sorted_original), len(sorted_cartoonized), len(shuffled_prompts))
# for i in range(min_length):
#     temp.append(("/content/drive/MyDrive/data/" + sorted_original[i], shuffled_prompts[i], "/content/drive/MyDrive/data/" + sorted_cartoonized[i]))

# %% [markdown]
# ### For single prompt

# %%
pr="Generate a fantasy version, retain hair and facial features, 8k"

# %%
# temp = []
# min_length = min(len(original), len(prompts), len(cartoonized))
# for i in range(min_length):
#     temp.append(("data/" + original[i], prompts[i], "data/" + cartoonized[i]))

# %%
sorted_original = sorted(original)
sorted_cartoonized = sorted(cartoonized)

temp = []
for i in range(len(sorted_original)):
  temp.append(("/content/drive/MyDrive/data/"+sorted_original[i],pr,"/content/drive/MyDrive/data/"+sorted_cartoonized[i]))

# %%
temp
# Out:
# [('/content/drive/MyDrive/data/Aishwarya Rajesh.jpeg',
#   'Generate a fantasy version, retain hair and facial features, 8k',
#   '/content/drive/MyDrive/data/Aishwarya Rajesh-gen.jpeg'),
#  ('/content/drive/MyDrive/data/Amrita Rao.jpeg',
#   'Generate a fantasy version, retain hair and facial features, 8k',
#   '/content/drive/MyDrive/data/Amrita Rao-gen.jpeg'),
#  ('/content/drive/MyDrive/data/Anu Emmanuel.jpeg',
#   'Generate a fantasy version, retain hair and facial features, 8k',
#   '/content/drive/MyDrive/data/Anu Emmanuel-gen.jpeg'),
#  ('/content/drive/MyDrive/data/Asin Thottumkal copy.jpg',
#   'Generate a fantasy version, retain hair and facial features, 8k',
#   '/content/drive/MyDrive/data/Asin Thottumkal-gen.jpg'),
#  ('/content/drive/MyDrive/data/Catherine Tresa.jpeg',
#   'Generate a fantasy version, retain hair and facial features, 8k',
#   '/content/drive/MyDrive/data/Catherine Tresa-gen.jpeg'),
#  ("/content/drive/MyDrive/data/Genelia D'Souza.jpeg",
# ...

# %%
path = "/content/drive/MyDrive/data"

# %%
dd = datasets.load_dataset("imagefolder",data_dir="/content/drive/MyDrive/data")

# %%
dd
# Out:
# DatasetDict({
#     validation: Dataset({
#         features: ['image'],
#         num_rows: 1
#     })
# })

# %%
dt['train'][0]
# Out:
# {'original_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1305>,
#  'edit_prompt': 'Generate a fantasy version, retain hair and facial features, 8k',
#  'cartoonized_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=578x1024>}

# %%
from typing import List

import numpy as np
from datasets import Dataset, Features
from datasets import Image as ImageFeature
from datasets import Value

# %%
#DS_NAME = "ranga-godhandaraman/fantasy-data"
DS_NAME="gundala31yash/illustrate_dataset"

# %%
def generate_examples(data_paths: List[str]):
    def fn():
        for data_path in data_paths:
            yield {
                "original_image": {"path": data_path[0]},
                "edit_prompt": data_path[1],
                "cartoonized_image": {"path": data_path[2]},
            }

    return fn

# %%
generation_fn = generate_examples(temp)
print("Creating dataset...")
ds = Dataset.from_generator(
    generation_fn,
    features=Features(
        original_image=ImageFeature(),
        edit_prompt=Value("string"),
        cartoonized_image=ImageFeature(),
    ),
)
# Out:
# Creating dataset...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
ds[0]
# Out:
# {'original_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1305>,
#  'edit_prompt': 'Generate a fantasy version, retain hair and facial features, 8k',
#  'cartoonized_image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=578x1024>}

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# ...

# %%
ds.push_to_hub(DS_NAME)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/370 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/gundala31yash/illustrate_dataset/commit/1374ad81d649a23f901517c5d2f0f99a77465619', commit_message='Upload dataset', commit_description='', oid='1374ad81d649a23f901517c5d2f0f99a77465619', pr_url=None, pr_revision=None, pr_num=None)
